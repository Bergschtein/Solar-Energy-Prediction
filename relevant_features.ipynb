# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns #For heatmap

# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
from tsfresh.feature_selection.relevance import calculate_relevance_table
from tsfresh import extract_relevant_features

# %%
train_a = pd.read_parquet('data/A/train_targets.parquet')
train_b = pd.read_parquet('data/B/train_targets.parquet')
train_c = pd.read_parquet('data/C/train_targets.parquet')

# Estimated training data for each location
X_train_estimated_a = pd.read_parquet('data/A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet('data/B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet('data/C/X_train_estimated.parquet')

# Observed training data for each location
X_train_observed_a = pd.read_parquet('data/A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet('data/B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet('data/C/X_train_observed.parquet')

# Estimated test data for each location
X_test_estimated_a = pd.read_parquet('data/A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet('data/B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet('data/C/X_test_estimated.parquet')

# %%
train_merge = pd.read_parquet('data/merge/train_merge.parquet')
print(train_merge.iloc[1:100])
# Out:
#                   time  pv_measurement location
# 0  2018-12-31 23:00:00             NaN        C
# 1  2019-01-01 00:00:00             NaN        C
# 1  2019-01-01 00:00:00          0.0000        B
# 2  2019-01-01 01:00:00          0.0000        B
# 2  2019-01-01 01:00:00             NaN        C
# 3  2019-01-01 02:00:00             NaN        C
# 3  2019-01-01 02:00:00          0.0000        B
# 4  2019-01-01 03:00:00          0.0000        B
# 4  2019-01-01 03:00:00             NaN        C
# 5  2019-01-01 04:00:00          0.0000        B
# 5  2019-01-01 04:00:00             NaN        C
# 6  2019-01-01 05:00:00             NaN        C
# 6  2019-01-01 05:00:00          0.0000        B
# 7  2019-01-01 06:00:00             NaN        C
# 7  2019-01-01 06:00:00          0.0000        B
# 8  2019-01-01 07:00:00             NaN        C
# 8  2019-01-01 07:00:00          0.0000        B
# 9  2019-01-01 08:00:00             NaN        C
# 9  2019-01-01 08:00:00          0.0000        B
# 10 2019-01-01 09:00:00             NaN        C
# 10 2019-01-01 09:00:00          0.0000        B
# 11 2019-01-01 10:00:00             NaN        C
# 11 2019-01-01 10:00:00          0.8625        B
# 12 2019-01-01 11:00:00         10.3500        B
# 12 2019-01-01 11:00:00             NaN        C
# 13 2019-01-01 12:00:00          5.1750        B
# 13 2019-01-01 12:00:00             NaN        C
# 14 2019-01-01 13:00:00             NaN        C
# 14 2019-01-01 13:00:00          0.8625        B
# 15 2019-01-01 14:00:00          0.0000        B
# 15 2019-01-01 14:00:00             NaN        C
# 16 2019-01-01 15:00:00          0.0000        B
# 16 2019-01-01 15:00:00             NaN        C
# 17 2019-01-01 16:00:00          0.0000        B
# 17 2019-01-01 16:00:00             NaN        C
# 18 2019-01-01 17:00:00             NaN        C
# 18 2019-01-01 17:00:00          0.0000        B
# 19 2019-01-01 18:00:00          0.0000        B
# 19 2019-01-01 18:00:00             NaN        C
# 20 2019-01-01 19:00:00          0.0000        B
# 20 2019-01-01 19:00:00             NaN        C
# 21 2019-01-01 20:00:00          0.0000        B
# 21 2019-01-01 20:00:00             NaN        C
# 22 2019-01-01 21:00:00          0.0000        B
# 22 2019-01-01 21:00:00             NaN        C
# 23 2019-01-01 22:00:00          0.0000        B
# 23 2019-01-01 22:00:00             NaN        C
# 24 2019-01-01 23:00:00             NaN        C
# 24 2019-01-01 23:00:00          0.0000        B
# 25 2019-01-02 00:00:00             NaN        C
# 25 2019-01-02 00:00:00          0.0000        B
# 26 2019-01-02 01:00:00             NaN        C
# 26 2019-01-02 01:00:00          0.0000        B
# 27 2019-01-02 02:00:00             NaN        C
# 27 2019-01-02 02:00:00          0.0000        B
# 28 2019-01-02 03:00:00             NaN        C
# 28 2019-01-02 03:00:00          0.0000        B
# 29 2019-01-02 04:00:00          0.0000        B
# 29 2019-01-02 04:00:00             NaN        C
# 30 2019-01-02 05:00:00          0.0000        B
# 30 2019-01-02 05:00:00             NaN        C
# 31 2019-01-02 06:00:00             NaN        C
# 31 2019-01-02 06:00:00          0.0000        B
# 32 2019-01-02 07:00:00             NaN        C
# 32 2019-01-02 07:00:00          0.0000        B
# 33 2019-01-02 08:00:00          0.0000        B
# 33 2019-01-02 08:00:00             NaN        C
# 34 2019-01-02 09:00:00          0.0000        B
# 34 2019-01-02 09:00:00             NaN        C
# 35 2019-01-02 10:00:00          3.4500        B
# 35 2019-01-02 10:00:00             NaN        C
# 36 2019-01-02 11:00:00          5.1750        B
# 36 2019-01-02 11:00:00             NaN        C
# 37 2019-01-02 12:00:00             NaN        C
# 37 2019-01-02 12:00:00          0.8625        B
# 38 2019-01-02 13:00:00          0.0000        B
# 38 2019-01-02 13:00:00             NaN        C
# 39 2019-01-02 14:00:00          0.0000        B
# 39 2019-01-02 14:00:00             NaN        C
# 40 2019-01-02 15:00:00             NaN        C
# 40 2019-01-02 15:00:00          0.0000        B
# 41 2019-01-02 16:00:00          0.0000        B
# 41 2019-01-02 16:00:00             NaN        C
# 42 2019-01-02 17:00:00          0.0000        B
# 42 2019-01-02 17:00:00             NaN        C
# 43 2019-01-02 18:00:00             NaN        C
# 43 2019-01-02 18:00:00          0.0000        B
# 44 2019-01-02 19:00:00             NaN        C
# 44 2019-01-02 19:00:00          0.0000        B
# 45 2019-01-02 20:00:00             NaN        C
# 45 2019-01-02 20:00:00          0.0000        B
# 46 2019-01-02 21:00:00          0.0000        B
# 46 2019-01-02 21:00:00             NaN        C
# 47 2019-01-02 22:00:00             NaN        C
# 47 2019-01-02 22:00:00          0.0000        B
# 48 2019-01-02 23:00:00          0.0000        B
# 48 2019-01-02 23:00:00             NaN        C
# 49 2019-01-03 00:00:00          0.0000        B
# 49 2019-01-03 00:00:00             NaN        C

# %% [markdown]
# #### Dummy preprocessing
#
# Checking lengths

# %%
print("X_train_estimated_a shape:", X_train_estimated_a.shape)
print("X_train_observed_a shape:", X_train_observed_a.shape)
print("Observed + estimated length", X_train_estimated_a.shape[0] + X_train_observed_a.shape[0])
print("Target value a shape:", train_a.shape)
# Out:
# X_train_estimated_a shape: (17576, 47)
# X_train_observed_a shape: (118669, 46)
# Observed + estimated length 136245
# Target value a shape: (34085, 2)

# %%
print("time range target values: ", min(train_a.loc[:, 'time']), '-', max(train_a.loc[:, 'time']))
# Out:
# time range target values:  2019-06-02 22:00:00 - 2023-04-30 23:00:00
# time range values

# %% [markdown]
# Merging observed data on location A with target values. This way the dataset will contain datapoints for the same time values. Makes it easier to look at how observed values effect target.

# %%
X_train_observed_a.rename(columns={'date_forecast': 'time'}, inplace=True)
X_train_observed_a.loc[:10, 'time'] #quick check
# Out:
# 0    2019-06-02 22:00:00
# 1    2019-06-02 22:15:00
# 2    2019-06-02 22:30:00
# 3    2019-06-02 22:45:00
# 4    2019-06-02 23:00:00
# 5    2019-06-02 23:15:00
# 6    2019-06-02 23:30:00
# 7    2019-06-02 23:45:00
# 8    2019-06-03 00:00:00
# 9    2019-06-03 00:15:00
# 10   2019-06-03 00:30:00
# Name: time, dtype: datetime64[us]

# %%
merge_temp = pd.merge(train_a, X_train_observed_a, on='time')
merge_temp_dropped_NaN = merge_temp.dropna()
merge_temp_replaced_Nan_w_zero = merge_temp.fillna(0)
merge_temp_cols = merge_temp.columns

# %%
Y_no_Nan = merge_temp_dropped_NaN['pv_measurement']
X_no_Nan = merge_temp_dropped_NaN.drop(columns=['time', 'pv_measurement'])
Y_Nan_is_zeros = merge_temp_replaced_Nan_w_zero['pv_measurement']
X_Nan_is_zeros = merge_temp_replaced_Nan_w_zero.drop(columns=['time', 'pv_measurement'])

# %%
print("Y shape NaN rows removed: ", Y_no_Nan.shape)
print("X shape NaN rows removed:", X_no_Nan.shape)
print("Y shape Nan replaced with zero:", Y_Nan_is_zeros.shape)
print("X shape Nan replaced with zero:", X_Nan_is_zeros.shape)
# Out:
# Y shape NaN rows removed:  (485,)
# X shape NaN rows removed: (485, 45)
# Y shape Nan replaced with zero: (29667,)
# X shape Nan replaced with zero: (29667, 45)

# %% [markdown]
# Relevance table for dataset where Nan rows are removed:

# %%
calculate_relevance_table(X_no_Nan, Y_no_Nan)
# Out:
#                                                        feature      type  \
# feature
# diffuse_rad:W                                    diffuse_rad:W      real
# clear_sky_rad:W                                clear_sky_rad:W      real
# diffuse_rad_1h:J                              diffuse_rad_1h:J      real
# clear_sky_energy_1h:J                    clear_sky_energy_1h:J      real
# is_day:idx                                          is_day:idx    binary
# direct_rad:W                                      direct_rad:W      real
# is_in_shadow:idx                              is_in_shadow:idx    binary
# sun_elevation:d                                sun_elevation:d      real
# direct_rad_1h:J                                direct_rad_1h:J      real
# visibility:m                                      visibility:m      real
# cloud_base_agl:m                              cloud_base_agl:m      real
# relative_humidity_1000hPa:p        relative_humidity_1000hPa:p      real
# t_1000hPa:K                                        t_1000hPa:K      real
# ceiling_height_agl:m                      ceiling_height_agl:m      real
# dew_point_2m:K                                  dew_point_2m:K      real
# wind_speed_v_10m:ms                        wind_speed_v_10m:ms      real
# super_cooled_liquid_water:kgm2  super_cooled_liquid_water:kgm2      real
# wind_speed_u_10m:ms                        wind_speed_u_10m:ms      real
# snow_depth:cm                                    snow_depth:cm      real
# absolute_humidity_2m:gm3              absolute_humidity_2m:gm3      real
# wind_speed_10m:ms                            wind_speed_10m:ms      real
# precip_5min:mm                                  precip_5min:mm      real
# precip_type_5min:idx                      precip_type_5min:idx      real
# effective_cloud_cover:p                effective_cloud_cover:p      real
# msl_pressure:hPa                              msl_pressure:hPa      real
# sfc_pressure:hPa                              sfc_pressure:hPa      real
# pressure_50m:hPa                              pressure_50m:hPa      real
# pressure_100m:hPa                            pressure_100m:hPa      real
# total_cloud_cover:p                        total_cloud_cover:p      real
# fresh_snow_1h:cm                              fresh_snow_1h:cm      real
# rain_water:kgm2                                rain_water:kgm2      real
# snow_melt_10min:mm                          snow_melt_10min:mm      real
# fresh_snow_24h:cm                            fresh_snow_24h:cm      real
# fresh_snow_6h:cm                              fresh_snow_6h:cm      real
# snow_water:kgm2                                snow_water:kgm2      real
# fresh_snow_12h:cm                            fresh_snow_12h:cm      real
# air_density_2m:kgm3                        air_density_2m:kgm3      real
# fresh_snow_3h:cm                              fresh_snow_3h:cm      real
# sun_azimuth:d                                    sun_azimuth:d      real
# dew_or_rime:idx                                dew_or_rime:idx  constant
# elevation:m                                        elevation:m  constant
# prob_rime:p                                        prob_rime:p  constant
# snow_density:kgm3                            snow_density:kgm3  constant
# snow_drift:idx                                  snow_drift:idx  constant
# wind_speed_w_1000hPa:ms                wind_speed_w_1000hPa:ms  constant
#
#                                      p_value  relevant
# feature
# diffuse_rad:W                   3.545998e-98      True
# clear_sky_rad:W                 2.431672e-95      True
# diffuse_rad_1h:J                7.167294e-86      True
# clear_sky_energy_1h:J           3.017082e-83      True
# is_day:idx                      3.355588e-82      True
# direct_rad:W                    3.982326e-80      True
# is_in_shadow:idx                3.272072e-79      True
# sun_elevation:d                 1.689667e-78      True
# direct_rad_1h:J                 9.210045e-77      True
# visibility:m                    5.373702e-12      True
# cloud_base_agl:m                4.897394e-04      True
# relative_humidity_1000hPa:p     3.153472e-03      True
# t_1000hPa:K                     1.630311e-02     False
# ceiling_height_agl:m            2.138321e-02     False
# dew_point_2m:K                  2.747203e-02     False
# wind_speed_v_10m:ms             2.898890e-02     False
# super_cooled_liquid_water:kgm2  3.634380e-02     False
# wind_speed_u_10m:ms             3.700199e-02     False
# snow_depth:cm                   4.027853e-02     False
# absolute_humidity_2m:gm3        4.287887e-02     False
# wind_speed_10m:ms               4.501499e-02     False
# precip_5min:mm                  5.105007e-02     False
# precip_type_5min:idx            5.136242e-02     False
# effective_cloud_cover:p         1.353769e-01     False
# msl_pressure:hPa                2.018879e-01     False
# sfc_pressure:hPa                2.604047e-01     False
# pressure_50m:hPa                2.646291e-01     False
# pressure_100m:hPa               2.726177e-01     False
# total_cloud_cover:p             3.531401e-01     False
# fresh_snow_1h:cm                4.300150e-01     False
# rain_water:kgm2                 4.450499e-01     False
# snow_melt_10min:mm              5.341931e-01     False
# fresh_snow_24h:cm               6.405305e-01     False
# fresh_snow_6h:cm                6.528481e-01     False
# snow_water:kgm2                 6.574231e-01     False
# fresh_snow_12h:cm               7.592304e-01     False
# air_density_2m:kgm3             7.614323e-01     False
# fresh_snow_3h:cm                7.734523e-01     False
# sun_azimuth:d                   9.907262e-01     False
# dew_or_rime:idx                          NaN     False
# elevation:m                              NaN     False
# prob_rime:p                              NaN     False
# snow_density:kgm3                        NaN     False
# snow_drift:idx                           NaN     False
# wind_speed_w_1000hPa:ms                  NaN     False

# %% [markdown]
# Relevance table where Nan is replaced with zero:

# %%
calculate_relevance_table(X_Nan_is_zeros, Y_Nan_is_zeros)
# Out:
#                                                        feature      type  \
# feature
# absolute_humidity_2m:gm3              absolute_humidity_2m:gm3      real
# air_density_2m:kgm3                        air_density_2m:kgm3      real
# is_in_shadow:idx                              is_in_shadow:idx    binary
# clear_sky_energy_1h:J                    clear_sky_energy_1h:J      real
# clear_sky_rad:W                                clear_sky_rad:W      real
# is_day:idx                                          is_day:idx    binary
# wind_speed_v_10m:ms                        wind_speed_v_10m:ms      real
# dew_point_2m:K                                  dew_point_2m:K      real
# diffuse_rad:W                                    diffuse_rad:W      real
# diffuse_rad_1h:J                              diffuse_rad_1h:J      real
# direct_rad:W                                      direct_rad:W      real
# direct_rad_1h:J                                direct_rad_1h:J      real
# t_1000hPa:K                                        t_1000hPa:K      real
# sun_elevation:d                                sun_elevation:d      real
# relative_humidity_1000hPa:p        relative_humidity_1000hPa:p      real
# pressure_100m:hPa                            pressure_100m:hPa      real
# msl_pressure:hPa                              msl_pressure:hPa      real
# pressure_50m:hPa                              pressure_50m:hPa      real
# sfc_pressure:hPa                              sfc_pressure:hPa      real
# visibility:m                                      visibility:m      real
# total_cloud_cover:p                        total_cloud_cover:p      real
# snow_water:kgm2                                snow_water:kgm2      real
# effective_cloud_cover:p                effective_cloud_cover:p      real
# fresh_snow_24h:cm                            fresh_snow_24h:cm      real
# prob_rime:p                                        prob_rime:p      real
# sun_azimuth:d                                    sun_azimuth:d      real
# dew_or_rime:idx                                dew_or_rime:idx      real
# fresh_snow_12h:cm                            fresh_snow_12h:cm      real
# fresh_snow_6h:cm                              fresh_snow_6h:cm      real
# snow_depth:cm                                    snow_depth:cm      real
# snow_density:kgm3                            snow_density:kgm3    binary
# fresh_snow_3h:cm                              fresh_snow_3h:cm      real
# fresh_snow_1h:cm                              fresh_snow_1h:cm      real
# precip_type_5min:idx                      precip_type_5min:idx      real
# precip_5min:mm                                  precip_5min:mm      real
# super_cooled_liquid_water:kgm2  super_cooled_liquid_water:kgm2      real
# cloud_base_agl:m                              cloud_base_agl:m      real
# wind_speed_10m:ms                            wind_speed_10m:ms      real
# snow_melt_10min:mm                          snow_melt_10min:mm      real
# rain_water:kgm2                                rain_water:kgm2      real
# wind_speed_u_10m:ms                        wind_speed_u_10m:ms      real
# ceiling_height_agl:m                      ceiling_height_agl:m      real
# wind_speed_w_1000hPa:ms                wind_speed_w_1000hPa:ms    binary
# elevation:m                                        elevation:m  constant
# snow_drift:idx                                  snow_drift:idx  constant
#
#                                       p_value  relevant
# feature
# absolute_humidity_2m:gm3         0.000000e+00      True
# air_density_2m:kgm3              0.000000e+00      True
# is_in_shadow:idx                 0.000000e+00      True
# clear_sky_energy_1h:J            0.000000e+00      True
# clear_sky_rad:W                  0.000000e+00      True
# is_day:idx                       0.000000e+00      True
# wind_speed_v_10m:ms              0.000000e+00      True
# dew_point_2m:K                   0.000000e+00      True
# diffuse_rad:W                    0.000000e+00      True
# diffuse_rad_1h:J                 0.000000e+00      True
# direct_rad:W                     0.000000e+00      True
# direct_rad_1h:J                  0.000000e+00      True
# t_1000hPa:K                      0.000000e+00      True
# sun_elevation:d                  0.000000e+00      True
# relative_humidity_1000hPa:p      0.000000e+00      True
# pressure_100m:hPa               4.058541e-210      True
# msl_pressure:hPa                1.225327e-209      True
# pressure_50m:hPa                3.262846e-197      True
# sfc_pressure:hPa                1.290101e-184      True
# visibility:m                    7.888852e-181      True
# total_cloud_cover:p             6.690312e-117      True
# snow_water:kgm2                 3.141531e-114      True
# effective_cloud_cover:p         3.272121e-110      True
# fresh_snow_24h:cm                1.227830e-98      True
# prob_rime:p                      2.178860e-63      True
# sun_azimuth:d                    4.519454e-61      True
# dew_or_rime:idx                  6.240952e-60      True
# fresh_snow_12h:cm                4.830191e-59      True
# fresh_snow_6h:cm                 1.012834e-49      True
# snow_depth:cm                    3.096861e-44      True
# snow_density:kgm3                1.022227e-42      True
# fresh_snow_3h:cm                 5.794477e-40      True
# fresh_snow_1h:cm                 4.466381e-26      True
# precip_type_5min:idx             5.825188e-22      True
# precip_5min:mm                   1.995325e-21      True
# super_cooled_liquid_water:kgm2   8.589473e-19      True
# cloud_base_agl:m                 1.987411e-14      True
# wind_speed_10m:ms                4.448493e-14      True
# snow_melt_10min:mm               6.128594e-06      True
# rain_water:kgm2                  3.933301e-04      True
# wind_speed_u_10m:ms              1.336755e-02     False
# ceiling_height_agl:m             3.655369e-02     False
# wind_speed_w_1000hPa:ms          3.298643e-01     False
# elevation:m                               NaN     False
# snow_drift:idx                            NaN     False

# %% [markdown]
# ### Same for merge

# %%
X_observed = pd.read_parquet('data/merge/X_train_observed_merge.parquet')
X_estimated = pd.read_parquet('data/merge/X_train_estimated_merge.parquet')
Y = pd.read_parquet('data/merge/train_merge.parquet')

X_observed.rename(columns={'date_forecast': 'time'}, inplace=True)

merged_df = pd.merge(X_observed, Y, on='time')
merged_df_no_NaN = merged_df.dropna()

print(merged_df.shape)

X = merged_df.drop(columns=['time', 'pv_measurement'])
Y = merged_df['pv_measurement']

calculate_relevance_table(X, Y)
# Out:
# (7665, 49)
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/erlendlokna/miniconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/erlendlokna/miniconda3/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py", line 185, in target_real_feature_real_test
#     _check_for_nans(x, y)
#   File "/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py", line 275, in _check_for_nans
#     if np.isnan(x.values).any():
#        ^^^^^^^^^^^^^^^^^^
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/relevant_features.ipynb Cell 19 line 1
#      <a href='vscode-notebook-cell:/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/relevant_features.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a> X = merged_df.drop(columns=['time', 'pv_measurement'])
#      <a href='vscode-notebook-cell:/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/relevant_features.ipynb#X31sZmlsZQ%3D%3D?line=12'>13</a> Y = merged_df['pv_measurement']
# ---> <a href='vscode-notebook-cell:/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/relevant_features.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a> calculate_relevance_table(X, Y)
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/relevance.py:286, in calculate_relevance_table(X, y, ml_task, multiclass, n_significant, n_jobs, show_warnings, chunksize, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent)
#     284     _test_real_feature = partial(target_real_feature_real_test, y=y)
#     285     _test_binary_feature = partial(target_real_feature_binary_test, y=y)
# --> 286     relevance_table = _calculate_relevance_table_for_implicit_target(
#     287         table_real,
#     288         table_binary,
#     289         X,
#     290         _test_real_feature,
#     291         _test_binary_feature,
#     292         hypotheses_independent,
#     293         fdr_level,
#     294         map_function,
#     295     )
#     297 if n_jobs < 0 or n_jobs > 1:
#     298     pool.close()
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/relevance.py:334, in _calculate_relevance_table_for_implicit_target(table_real, table_binary, X, test_real_feature, test_binary_feature, hypotheses_independent, fdr_level, map_function)
#     323 def _calculate_relevance_table_for_implicit_target(
#     324     table_real,
#     325     table_binary,
#    (...)
#     331     map_function,
#     332 ):
#     333     table_real["p_value"] = pd.Series(
# --> 334         map_function(test_real_feature, [X[feature] for feature in table_real.index]),
#     335         index=table_real.index,
#     336     )
#     337     table_binary["p_value"] = pd.Series(
#     338         map_function(
#     339             test_binary_feature, [X[feature] for feature in table_binary.index]
#     340         ),
#     341         index=table_binary.index,
#     342     )
#     343     relevance_table = pd.concat([table_real, table_binary])
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:125, in worker()
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:48, in mapstar()
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py:185, in target_real_feature_real_test()
#     171 """
#     172 Calculate the feature significance of a real-valued feature to a real-valued target as a p-value.
#     173 Use `Kendall's tau` from :func:`~scipy.stats.kendalltau` for this.
#    (...)
#     182 :rtype: float
#     183 """
#     184 __check_if_pandas_series(x, y)
# --> 185 _check_for_nans(x, y)
#     187 tau, p_value = stats.kendalltau(x, y, method="asymptotic")
#     188 return p_value
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py:275, in _check_for_nans()
#     266 def _check_for_nans(x, y):
#     267     """
#     268     Helper function to check if target or feature contains NaNs.
#     269     :param x: A feature
#    (...)
#     273     :raises: `ValueError` if target or feature contains NaNs.
#     274     """
# --> 275     if np.isnan(x.values).any():
#     276         raise ValueError("Feature {} contains NaN values".format(x.name))
#     277     elif np.isnan(y.values).any():
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
calculate_relevance_table()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_34511/2373778956.py in ?()
# ----> 1 merged_df = pd.merge(X_observed, Y, on='time').dropna()
#
# ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1265                         # Then we're either Hashable or a wrong-length arraylike,
#    1266                         #  the latter of which will raise
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#    1272                             right_keys.append(right.index._values)
#
# ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'time'

# %%
calculate_relevance_table(X, Y)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/erlendlokna/miniconda3/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/erlendlokna/miniconda3/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py", line 185, in target_real_feature_real_test
#     _check_for_nans(x, y)
#   File "/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py", line 275, in _check_for_nans
#     if np.isnan(x.values).any():
#        ^^^^^^^^^^^^^^^^^^
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/relevant_features.ipynb Cell 21 line 1
# ----> <a href='vscode-notebook-cell:/home/erlendlokna/Documents/ntnu/machinelearning/Solar-Energy-Prediction/relevant_features.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> calculate_relevance_table(X, Y)
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/relevance.py:286, in calculate_relevance_table(X, y, ml_task, multiclass, n_significant, n_jobs, show_warnings, chunksize, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent)
#     284     _test_real_feature = partial(target_real_feature_real_test, y=y)
#     285     _test_binary_feature = partial(target_real_feature_binary_test, y=y)
# --> 286     relevance_table = _calculate_relevance_table_for_implicit_target(
#     287         table_real,
#     288         table_binary,
#     289         X,
#     290         _test_real_feature,
#     291         _test_binary_feature,
#     292         hypotheses_independent,
#     293         fdr_level,
#     294         map_function,
#     295     )
#     297 if n_jobs < 0 or n_jobs > 1:
#     298     pool.close()
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/relevance.py:334, in _calculate_relevance_table_for_implicit_target(table_real, table_binary, X, test_real_feature, test_binary_feature, hypotheses_independent, fdr_level, map_function)
#     323 def _calculate_relevance_table_for_implicit_target(
#     324     table_real,
#     325     table_binary,
#    (...)
#     331     map_function,
#     332 ):
#     333     table_real["p_value"] = pd.Series(
# --> 334         map_function(test_real_feature, [X[feature] for feature in table_real.index]),
#     335         index=table_real.index,
#     336     )
#     337     table_binary["p_value"] = pd.Series(
#     338         map_function(
#     339             test_binary_feature, [X[feature] for feature in table_binary.index]
#     340         ),
#     341         index=table_binary.index,
#     342     )
#     343     relevance_table = pd.concat([table_real, table_binary])
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:125, in worker()
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~/miniconda3/lib/python3.11/multiprocessing/pool.py:48, in mapstar()
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py:185, in target_real_feature_real_test()
#     171 """
#     172 Calculate the feature significance of a real-valued feature to a real-valued target as a p-value.
#     173 Use `Kendall's tau` from :func:`~scipy.stats.kendalltau` for this.
#    (...)
#     182 :rtype: float
#     183 """
#     184 __check_if_pandas_series(x, y)
# --> 185 _check_for_nans(x, y)
#     187 tau, p_value = stats.kendalltau(x, y, method="asymptotic")
#     188 return p_value
#
# File ~/Documents/ntnu/machinelearning/Solar-Energy-Prediction/.venv/lib/python3.11/site-packages/tsfresh/feature_selection/significance_tests.py:275, in _check_for_nans()
#     266 def _check_for_nans(x, y):
#     267     """
#     268     Helper function to check if target or feature contains NaNs.
#     269     :param x: A feature
#    (...)
#     273     :raises: `ValueError` if target or feature contains NaNs.
#     274     """
# --> 275     if np.isnan(x.values).any():
#     276         raise ValueError("Feature {} contains NaN values".format(x.name))
#     277     elif np.isnan(y.values).any():
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
